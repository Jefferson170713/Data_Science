# %% [markdown]
# # Teste com groupby.

# %%
import pandas as pd
dados = pd.read_excel('BaseDeDados_Tabela.xlsx')
df = pd.DataFrame(dados)
df.head()
# Out:
#         DATA        LOJA                     CATEGORIA     GÊNERO  VOLUME  \
# 0 2017-01-01     Uberaba  Cosméticos e higiene pessoal  Masculino      15
# 1 2017-01-01     Uberaba             Comidas e bebidas   Feminino      13
# 2 2017-01-02    Araguari         Utilidades domésticas   Feminino       1
# 3 2017-01-02  Uberlândia  Cosméticos e higiene pessoal  Masculino       3
# 4 2017-01-02   Ituiutaba  Cosméticos e higiene pessoal   Feminino       8
#
#    VALOR FORMA DE PAGAMENTO
# 0     77             Débito
# 1    258            Crédito
# 2     25           Dinheiro
# 3     45             Débito
# 4    225             Débito

# %%
df.groupby(['LOJA','FORMA DE PAGAMENTO']).max()
# Out:
#                                     DATA              CATEGORIA     GÊNERO  \
# LOJA       FORMA DE PAGAMENTO
# Araguari   Crédito            2018-10-17  Utilidades domésticas  Masculino
#            Dinheiro           2018-10-20  Utilidades domésticas  Masculino
#            Débito             2018-10-24  Utilidades domésticas  Masculino
# Ituiutaba  Crédito            2018-10-29  Utilidades domésticas  Masculino
#            Dinheiro           2018-10-27  Utilidades domésticas  Masculino
#            Débito             2018-10-30  Utilidades domésticas  Masculino
# Uberaba    Crédito            2018-10-14  Utilidades domésticas  Masculino
#            Dinheiro           2018-10-28  Utilidades domésticas  Masculino
#            Débito             2018-10-30  Utilidades domésticas  Masculino
# Uberlândia Crédito            2018-10-29  Utilidades domésticas  Masculino
#            Dinheiro           2018-10-29  Utilidades domésticas  Masculino
# ...
