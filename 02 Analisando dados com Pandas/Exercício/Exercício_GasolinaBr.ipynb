# %% [markdown]
# # Exercício *Gasolina Do Brasil.*

# %% [markdown]
# ## Neste projeto, trabalharemos com dois arquivos csvs separados, contendo informações sobre o preço da gasolina no Brasil.
#
# ### 1. Carregue os conjuntos de dados "gasolina_2000+.csv" e "gasolina_2010+.csv" em dois DataFrames diferentes e combine-os em um único DataFrame.

# %%
import pandas as pd

# %%
df_1 = pd.read_csv('C:/Users/55859/Desktop/Estudos/Data Science/02 Analisando dados com Pandas/DataSetes/gasolina_2000+.csv', index_col = 0)

# %%
df_2 = pd.read_csv('C:/Users/55859/Desktop/Estudos/Data Science/02 Analisando dados com Pandas/DataSetes/gasolina_2010+.csv', index_col = 0)
# Out:
# C:\Users\55859\AppData\Local\Temp\ipykernel_6476\889668878.py:1: DtypeWarning: Columns (12,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2 = pd.read_csv('C:/Users/55859/Desktop/Estudos/Data Science/02 Analisando dados com Pandas/DataSetes/gasolina_2010+.csv', index_col = 0)

# %% [markdown]
# ### 2.Investigue as colunas e entenda o conjunto de dados usando o head() e info()

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42638 entries, 0 to 52806
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DATA INICIAL                   42638 non-null  object
#  1   DATA FINAL                     42638 non-null  object
#  2   REGIÃO                         42638 non-null  object
#  3   ESTADO                         42638 non-null  object
#  4   PRODUTO                        42638 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   42638 non-null  int64
#  6   UNIDADE DE MEDIDA              42638 non-null  object
#  7   PREÇO MÉDIO REVENDA            42638 non-null  float64
#  8   DESVIO PADRÃO REVENDA          42638 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           42638 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           42638 non-null  float64
#  11  MARGEM MÉDIA REVENDA           42638 non-null  object
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78185 entries, 9256 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DATA INICIAL                   78185 non-null  object
#  1   DATA FINAL                     78185 non-null  object
#  2   REGIÃO                         78185 non-null  object
#  3   ESTADO                         78185 non-null  object
#  4   PRODUTO                        78185 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   78185 non-null  int64
#  6   UNIDADE DE MEDIDA              78185 non-null  object
#  7   PREÇO MÉDIO REVENDA            78185 non-null  float64
#  8   DESVIO PADRÃO REVENDA          78185 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           78185 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           78185 non-null  float64
#  11  MARGEM MÉDIA REVENDA           78185 non-null  object
# ...

# %% [markdown]
# #### Agora vamos juntar os dois arquivos em um só.

# %%
df_1.head(3)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
df_2.head(3)
# Out:
#      DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 9256   2011-01-02  2011-01-08  CENTRO OESTE  DISTRITO FEDERAL
# 9257   2011-01-02  2011-01-08  CENTRO OESTE             GOIAS
# 9258   2011-01-02  2011-01-08  CENTRO OESTE       MATO GROSSO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 9256  ETANOL HIDRATADO                            80              R$/l
# 9257  ETANOL HIDRATADO                           255              R$/l
# 9258  ETANOL HIDRATADO                           141              R$/l
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 9256                2.030                  0.003                  2.02
# 9257                1.717                  0.102                  1.49
# 9258                1.848                  0.148                  1.59
#
#       PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# ...

# %% [markdown]
# ### 3. Selecione a terceira entrada da coluna DATA INICIAL e verifique seu tipo.

# %% [markdown]
# ##### Perceba que é interessante notar que os dois métodos retornam o valor da coluna correspondente ao que está dentro de loc ou iloc.

# %%
df_1['NÚMERO DE POSTOS PESQUISADOS'].loc[2]
# Out:
# 192

# %%
type(df_1['DATA INICIAL'])
# Out:
# pandas.core.series.Series

# %%
type(df_1['DATA INICIAL'].iloc[0])
# Out:
# str

# %%
df_2['NÚMERO DE POSTOS PESQUISADOS'].iloc[2]
# Out:
# 141

# %%
type(df_2['DATA INICIAL'])
# Out:
# pandas.core.series.Series

# %%
type(df_2['DATA INICIAL'].iloc[0])
# Out:
# str

# %% [markdown]
# ### 4. Você deve ter percebido que as colunas DATA INICIAL e DATA FINAL estão formatadas como string. Utilizando o método pd.to_datetime(), converta ambas colunas para Timestamp / Datetime.

# %%
df_1['DATA INICIAL'] = pd.to_datetime(df_1['DATA INICIAL'])

# %%
df_1['DATA FINAL'] = pd.to_datetime(df_1['DATA FINAL'])

# %%
type(df_1['DATA FINAL'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_2['DATA INICIAL'] = pd.to_datetime(df_2['DATA INICIAL'])

# %%
df_2['DATA FINAL'] = pd.to_datetime(df_2['DATA FINAL'])

# %%
type(df_2['DATA FINAL'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.concat([df_1, df_2])
df.head(5)
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
# ...

# %% [markdown]
# ### 5. Crie uma nova coluna para representar o ano e o mês(aaaa-mm), utilizando a coluna DATA FINAL como referência.

# %%
df['ANO - MÊS'] = df['DATA FINAL'].apply(lambda ano : "{}".format(ano.year)) + df['DATA FINAL'].apply(lambda mes : " - {:02d}".format(mes.month))

# %%
df.head(3)
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %% [markdown]
# ### 6. Utilizando o value_counts(), liste todos os tipos de produtos contidos na base de dados.'m

# %%
df['PRODUTO'].value_counts()
# Out:
# GASOLINA COMUM        23570
# GLP                   23561
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# GNV                   14469
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: PRODUTO, dtype: int64

# %%
df['REGIÃO'].value_counts()
# Out:
# NORDESTE        41671
# NORTE           27989
# SUDESTE         19270
# CENTRO OESTE    17449
# SUL             14444
# Name: REGIÃO, dtype: int64

# %%
df['ESTADO'].value_counts()
# Out:
# PARAIBA                4819
# RIO DE JANEIRO         4819
# SAO PAULO              4819
# RIO GRANDE DO SUL      4819
# BAHIA                  4819
# SANTA CATARINA         4818
# RIO GRANDE DO NORTE    4818
# MINAS GERAIS           4817
# ESPIRITO SANTO         4815
# PERNAMBUCO             4813
# CEARA                  4813
# PARANA                 4807
# ALAGOAS                4806
# SERGIPE                4795
# MATO GROSSO DO SUL     4793
# MATO GROSSO            4566
# AMAZONAS               4414
# GOIAS                  4134
# PIAUI                  4017
# MARANHAO               3971
# DISTRITO FEDERAL       3956
# PARA                   3955
# TOCANTINS              3953
# RONDONIA               3950
# ACRE                   3948
# RORAIMA                3938
# AMAPA                  3831
# Name: ESTADO, dtype: int64

# %% [markdown]
# ### 7. Filtre o DataFrame para obter apenas dados da 'GASOLINA COMUM'. Grave em uma nova variável.
# #### Detalhe importante é que eu poderia ter pego qualquer um deses:
#     GASOLINA COMUM
#     GLP
#     ETANOL HIDRATADO
#     ÓLEO DIESEL
#     GNV
#     ÓLEO DIESEL S10
#     OLEO DIESEL S10
#     OLEO DIESEL
#     GASOLINA ADITIVADA

# %%
df_amostra = df[df['PRODUTO'] == 'GASOLINA COMUM']
df_amostra
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO              ESTADO  \
# 12064    2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 12065    2004-05-09 2004-05-15  CENTRO OESTE               GOIAS
# 12066    2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO
# 12067    2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 12068    2004-05-09 2004-05-15      NORDESTE             ALAGOAS
# ...             ...        ...           ...                 ...
# 120721   2021-04-25 2021-05-01         NORTE             RORAIMA
# 120722   2021-04-25 2021-05-01           SUL      SANTA CATARINA
# 120723   2021-04-25 2021-05-01       SUDESTE           SAO PAULO
# 120724   2021-04-25 2021-05-01      NORDESTE             SERGIPE
# 120725   2021-04-25 2021-05-01         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12064   GASOLINA COMUM                           128              R$/l
# ...

# %% [markdown]
# ### 8. Qual o preço médio de revenda da gasolina em agosto de 2008?

# %%
df_amostra[df_amostra['ANO - MÊS'] == '2008 - 08']['PREÇO MÉDIO REVENDA'].mean()
# Out:
# 2.6012444444444447

# %%
df_amostra['ANO - MÊS'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 23570 entries, 12064 to 120725
# Series name: ANO - MÊS
# Non-Null Count  Dtype
# --------------  -----
# 23570 non-null  object
# dtypes: object(1)
# memory usage: 368.3+ KB

# %%
df_amostra[df_amostra['ANO - MÊS'] == '2004 - 06']['NÚMERO DE POSTOS PESQUISADOS']
# Out:
# 12145     144
# 12146     387
# 12147     199
# 12148     180
# 12149     108
#          ...
# 12248    1090
# 12249    4140
# 12250     748
# 12251     817
# 12252     520
# Name: NÚMERO DE POSTOS PESQUISADOS, Length: 108, dtype: int64

# %%
df_amostra[df_amostra['ESTADO'] == 'CEARA']
# Out:
#        DATA INICIAL DATA FINAL    REGIÃO ESTADO         PRODUTO  \
# 12070    2004-05-09 2004-05-15  NORDESTE  CEARA  GASOLINA COMUM
# 12097    2004-05-16 2004-05-22  NORDESTE  CEARA  GASOLINA COMUM
# 12124    2004-05-23 2004-05-29  NORDESTE  CEARA  GASOLINA COMUM
# 12151    2004-05-30 2004-06-05  NORDESTE  CEARA  GASOLINA COMUM
# 12178    2004-06-06 2004-06-12  NORDESTE  CEARA  GASOLINA COMUM
# ...             ...        ...       ...    ...             ...
# 119990   2021-03-28 2021-04-03  NORDESTE  CEARA  GASOLINA COMUM
# 120168   2021-04-04 2021-04-10  NORDESTE  CEARA  GASOLINA COMUM
# 120347   2021-04-11 2021-04-17  NORDESTE  CEARA  GASOLINA COMUM
# 120525   2021-04-18 2021-04-24  NORDESTE  CEARA  GASOLINA COMUM
# 120704   2021-04-25 2021-05-01  NORDESTE  CEARA  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12070                            321              R$/l                2.148
# ...

# %% [markdown]
# ### 9. Qual o preço médio de revenda da gasolina em maio de 2021 em Ceará?

# %%
df['ANO'] = df['DATA FINAL'].apply(lambda ano : '{}'.format(ano.year))
df['MÊS'] = df['DATA FINAL'].apply(lambda mes : '{}'.format(mes.month))
df.head(3)
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                  0.016                  1.19  ...                 0.463
# 1                  0.114                  0.89  ...                 0.399
# 2                  0.097                  1.18  ...                 0.419
#
#   COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
df[(df['ANO'] == '2021') & (df['MÊS'] == '5')]['PREÇO MÉDIO REVENDA']
# Out:
# 120645    5.048
# 120646    4.625
# 120647    4.750
# 120648    4.100
# 120649    4.074
#           ...
# 120818    4.582
# 120819    4.141
# 120820    4.246
# 120821    4.464
# 120822    4.352
# Name: PREÇO MÉDIO REVENDA, Length: 178, dtype: float64

# %%
df[(df['ANO'] == '2021') & (df['MÊS'] == '5')]['PREÇO MÉDIO REVENDA'].mean()
# Out:
# 17.502089887640455

# %% [markdown]
# ## Obs:
#    *Vamos observar o tamanho do arquivo em df.*

# %%
type(df['DATA INICIAL'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ### 10. Você conseguiria descobrir em qual(quais) estado(s) a gasolina ultrapassou a barreira dos R$ 5,00? E quando isso ocorreu?

# %%
df[(df['PRODUTO'] == 'GASOLINA COMUM') & (df['PREÇO MÉDIO REVENDA'] > 5)][['REGIÃO','ESTADO','PREÇO MÉDIO REVENDA','MÊS','ANO']]
# Out:
#               REGIÃO              ESTADO  PREÇO MÉDIO REVENDA MÊS   ANO
# 24132   CENTRO OESTE    DISTRITO FEDERAL               33.989   5  2004
# 24133   CENTRO OESTE               GOIAS               30.335   5  2004
# 24134   CENTRO OESTE         MATO GROSSO               38.568   5  2004
# 24135   CENTRO OESTE  MATO GROSSO DO SUL               33.388   5  2004
# 24136       NORDESTE             ALAGOAS               32.391   5  2004
# ...              ...                 ...                  ...  ..   ...
# 120750       SUDESTE           SAO PAULO               85.340   5  2021
# 120751      NORDESTE             SERGIPE               83.508   5  2021
# 120752         NORTE           TOCANTINS               93.867   5  2021
# 120769         NORTE                ACRE                5.550   5  2021
# 120796         NORTE                ACRE                5.209   5  2021
#
# [24304 rows x 5 columns]

# %% [markdown]
# ##### Repare que está é uma nova forma de mostrar o data frame. Ainda é o mesmo df, porém, de maneira análoga ao SQL, ele me retornou uma tabela reduzida
# ##### e somente com os valores especificados por mim.
#     Agora farei um teste, tentarei passar esses 353 linhas e 5 colunas para uma novo data frame.
#     Observe que, o novo dataFrame está modificado. não se parece com o df que é o original.

# %%
teste = pd.DataFrame(df[(df['PRODUTO'] == 'GASOLINA COMUM') & (df['PREÇO MÉDIO REVENDA'] > 5)][['REGIÃO','ESTADO','PREÇO MÉDIO REVENDA','ANO - MÊS']])
teste
# Out:
#           REGIÃO          ESTADO  PREÇO MÉDIO REVENDA  ANO - MÊS
# 98201      NORTE            ACRE                5.053  2018 - 05
# 98347      NORTE            ACRE                5.035  2018 - 06
# 98493      NORTE            ACRE                5.038  2018 - 06
# 98511    SUDESTE  RIO DE JANEIRO                5.016  2018 - 06
# 98646      NORTE            ACRE                5.031  2018 - 06
# ...          ...             ...                  ...        ...
# 120721     NORTE         RORAIMA                5.364  2021 - 05
# 120722       SUL  SANTA CATARINA                5.051  2021 - 05
# 120723   SUDESTE       SAO PAULO                5.265  2021 - 05
# 120724  NORDESTE         SERGIPE                5.586  2021 - 05
# 120725     NORTE       TOCANTINS                5.751  2021 - 05
#
# [353 rows x 4 columns]

# %% [markdown]
# ### 11. Qual a média de preço dos estados da região sul em 2012?

# %%
df["REGIÃO"].unique()
# Out:
# array(['CENTRO OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'],
#       dtype=object)

# %% [markdown]
# #### Olha o poder disso, eu posso simplesmente comlocar função em grupos e pegar somente o que eu quiser.

# %%
teste_aux = df[df['REGIÃO'] == 'NORDESTE']
teste_x = teste_aux.groupby(['ESTADO','ESTADO','ANO'])
teste_x.head()
# Out:
#        DATA INICIAL DATA FINAL    REGIÃO               ESTADO  \
# 4        2004-05-09 2004-05-15  NORDESTE              ALAGOAS
# 5        2004-05-09 2004-05-15  NORDESTE                BAHIA
# 6        2004-05-09 2004-05-15  NORDESTE                CEARA
# 7        2004-05-09 2004-05-15  NORDESTE             MARANHAO
# 8        2004-05-09 2004-05-15  NORDESTE              PARAIBA
# ...             ...        ...       ...                  ...
# 117746   2020-12-27 2021-01-02  NORDESTE           PERNAMBUCO
# 117748   2020-12-27 2021-01-02  NORDESTE  RIO GRANDE DO NORTE
# 117761   2020-12-27 2021-01-02  NORDESTE             MARANHAO
# 117767   2020-12-27 2021-01-02  NORDESTE                PIAUI
# 117775   2020-12-27 2021-01-02  NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 4       ETANOL HIDRATADO                           103              R$/l
# ...

# %% [markdown]
# ### Agora como faço para saber o nome dos estados da região SUL?
#     Simples, com a função unique(), ela retorna somente os únicos valores dos nomes dos estados da região sul.

# %%
teste_aux['ESTADO'].unique()
# Out:
# array(['ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE'], dtype=object)

# %%
teste_aux['ANO'].unique()
# Out:
# array(['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021'], dtype=object)

# %% [markdown]
# ### Agora respondendo a pergunta 11 !

# %%
teste_aux[teste_aux['ANO'] == '2012']['PREÇO MÉDIO REVENDA']
# Out:
# 10664    2.256
# 10665    2.090
# 10666    2.133
# 10667    2.211
# 10668    2.165
#          ...
# 55596    2.080
# 55597    2.134
# 55598    2.139
# 55599    2.117
# 55600    2.149
# Name: PREÇO MÉDIO REVENDA, Length: 2236, dtype: float64

# %% [markdown]
# ### Agora o preço médio de todos os valores do ano de 2012 para a região do sul.

# %%
teste_aux2 = df[(df["DATA FINAL"].apply(lambda x: x.year) == 2012)]
teste_aux2[teste_aux2["REGIÃO"] == "SUL"]["PREÇO MÉDIO REVENDA"].mean()
# Out:
# 9.842052564102566

# %% [markdown]
# ### 12. Você conseguiria obter uma tabela contendo a variação percentual ano a ano para o estado do Ceará?

# %%
df['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
df.head(2)
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                  0.016                  1.19  ...                 0.463
# 1                  0.114                  0.89  ...                 0.399
#
#   COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                    0.012                     0.825
# 1                    0.098                     0.763
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# ...

# %%
#tst = df[df['PREÇO MÉDIO REVENDA'] > 5]#['ESTADO','REGIÃO','ANO - MÊS', 'PREÇO MÍNIMO REVENDA', 'PREÇO MÁXIMO REVENDA']
#tst['ANO - MÊS']
df[df['ESTADO'] == 'CEARA'][['PREÇO MÉDIO REVENDA','ANO']]
# Out:
#         PREÇO MÉDIO REVENDA   ANO
# 6                     1.453  2004
# 33                    1.451  2004
# 60                    1.443  2004
# 87                    1.442  2004
# 114                   1.445  2004
# ...                     ...   ...
# 120704                5.490  2021
# 120731               91.672  2021
# 120755                3.726  2021
# 120774                4.424  2021
# 120801                4.380  2021
#
# [4813 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120823 entries, 0 to 120822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  datetime64[ns]
#  1   DATA FINAL                     120823 non-null  datetime64[ns]
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
# ...
