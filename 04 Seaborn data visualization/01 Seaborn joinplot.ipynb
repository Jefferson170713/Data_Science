# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_real'] = df['total_bill'] * df['size'] - (df['tip'] * df['size'])
df['total_sex'] = df['total_bill'] * df['size']
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_real  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2       31.96
# 1         10.34  1.66    Male     No   Sun  Dinner     3       26.04
# 2         21.01  3.50    Male     No   Sun  Dinner     3       52.53
# 3         23.68  3.31    Male     No   Sun  Dinner     2       40.74
# 4         24.59  3.61  Female     No   Sun  Dinner     4       83.92
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       69.33
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       50.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       41.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2       32.14
# 243       18.78  3.00  Female     No  Thur  Dinner     2       31.56
#
#      total_sex
# 0        33.98
# 1        31.02
# 2        63.03
# 3        47.36
# 4        98.36
# ..         ...
# 239      87.09
# ...

# %%
x1 = (df[df['sex'] == 'Male']['total_bill'] * df[df['sex'] == 'Male']['size'] - (df['tip'] * df['size']))
x2 = (df[df['sex'] == 'Female']['total_bill'] * df[df['sex'] == 'Female']['size'] - (df['tip'] * df['size']))

x1
# Out:
# 0        NaN
# 1      26.04
# 2      52.53
# 3      40.74
# 4        NaN
#        ...
# 239    69.33
# 240      NaN
# 241    41.34
# 242    32.14
# 243      NaN
# Length: 244, dtype: float64

# %%
x1.dropna()
# Out:
# 1      26.04
# 2      52.53
# 3      40.74
# 5      82.32
# 6      13.54
#        ...
# 236    23.20
# 237    63.32
# 239    69.33
# 241    41.34
# 242    32.14
# Length: 157, dtype: float64

# %%
x2.dropna()
# Out:
# 0       31.96
# 4       83.92
# 11     121.04
# 14      23.62
# 16      25.98
#         ...
# 226     16.18
# 229     38.48
# 238     93.48
# 240     50.36
# 243     31.56
# Length: 87, dtype: float64

# %%
sns.jointplot(x='total_bill', y='tip', data=df, color='red')

# %%
sns.jointplot(x= 'sex', y='total_real' , data=df)

# %%
sns.jointplot(x= 'day', y='total_real' , data=df)

# %%
sns.jointplot(x= 'total_real', y='day' , data=df)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_real  total_sex
# 0       16.99  1.01  Female     No  Sun  Dinner     2       31.96      33.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3       26.04      31.02
# 2       21.01  3.50    Male     No  Sun  Dinner     3       52.53      63.03

# %%
sns.jointplot(x= 'total_real', y='time' , data=df)

# %%
sns.jointplot(x= 'day', y='time' , data=df)

# %%
sns.jointplot(x= 'total_real', y='tip' , data=df, kind='reg')

# %%
sns.jointplot(x= 'total_real', y='tip' , data=df, kind='hist')

# %%
sns.jointplot(x= 'total_real', y='tip' , data=df, kind='hex')

# %%
sns.jointplot(x= 'total_real', y='tip' , data=df, kind='resid')

# %%
sns.jointplot(x= 'total_real', y='tip' , data=df, kind='kde')

# %%
sns.pairplot(df, kind='hist')

# %%
sns.pairplot(df, hue='sex') # separou por uma variável categórica

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_real  total_sex
# 0       16.99  1.01  Female     No  Sun  Dinner     2       31.96      33.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3       26.04      31.02

# %%
sns.pairplot(df, hue='time')

# %%
sns.pairplot(df, hue='day')

# %%
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
